# %% [markdown]
# # OASIS INFOBYTE INTERNSHIP TASK 2
# #### UNEMPLOYMENT ANALYSIS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mlt
import datetime as dt
import calendar
import matplotlib as mlp
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# %%
df=pd.read_csv('/kaggle/input/unemployment-in-india/Unemployment_Rate_upto_11_2020.csv')

# %%
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# ...

# %%
df.shape
# Out:
# (267, 9)

# %%
df.info
# Out:
# <bound method DataFrame.info of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %%
df=df.dropna()

# %%
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# ...

# %%
if (df.duplicated().sum()==0):
    print("NO DUPLICATE COLUMN")
else:
    print("THERE ARE",df.duplicated().sum(),"DUPLICATED COLUMN")
# Out:
# NO DUPLICATE COLUMN

# %%
df.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        267.000000         2.670000e+02
# mean                          12.236929         1.396211e+07
# std                           10.803283         1.336632e+07
# min                            0.500000         1.175420e+05
# 25%                            4.845000         2.838930e+06
# 50%                            9.650000         9.732417e+06
# 75%                           16.755000         2.187869e+07
# max                           75.850000         5.943376e+07
#
#         Estimated Labour Participation Rate (%)   longitude    latitude
# count                                267.000000  267.000000  267.000000
# mean                                  41.681573   22.826048   80.532425
# std                                    7.845419    6.270731    5.831738
# min                                   16.770000   10.850500   71.192400
# ...

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude'],
#       dtype='object')

# %%
df.columns=["state","date","frequency","estimated unemployment rate","estimated employed","estimated labour participation rate","region", "longitude", "latitude"]

# %%
df.state.value_counts()
# Out:
# Andhra Pradesh      10
# Assam               10
# Uttarakhand         10
# Uttar Pradesh       10
# Tripura             10
# Telangana           10
# Tamil Nadu          10
# Rajasthan           10
# Punjab              10
# Puducherry          10
# Odisha              10
# Meghalaya           10
# Maharashtra         10
# Madhya Pradesh      10
# Kerala              10
# Karnataka           10
# Jharkhand           10
# Himachal Pradesh    10
# Haryana             10
# Gujarat             10
# Goa                 10
# Delhi               10
# Chhattisgarh        10
# Bihar               10
# West Bengal         10
# Jammu & Kashmir      9
# Sikkim               8
# Name: state, dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
#to print the month of unemployment
df['date'] = pd.to_datetime(df['date'], dayfirst=True)
df['month_int'] =  df['date'].dt.month
df['month'] =  df['month_int'].apply(lambda x: calendar.month_abbr[x])
df.head()
# Out:
#             state       date frequency  estimated unemployment rate  \
# 0  Andhra Pradesh 2020-01-31         M                         5.48
# 1  Andhra Pradesh 2020-02-29         M                         5.83
# 2  Andhra Pradesh 2020-03-31         M                         5.79
# 3  Andhra Pradesh 2020-04-30         M                        20.51
# 4  Andhra Pradesh 2020-05-31         M                        17.43
#
#    estimated employed  estimated labour participation rate region  longitude  \
# 0            16635535                                41.02  South    15.9129
# 1            16545652                                40.90  South    15.9129
# 2            15881197                                39.18  South    15.9129
# 3            11336911                                33.10  South    15.9129
# 4            12988845                                36.46  South    15.9129
#
#    latitude  month_int month
# 0     79.74          1   Jan
# 1     79.74          2   Feb
# ...

# %%
stum = df[["state","estimated unemployment rate"]].groupby("state").sum().sort_values(by="estimated unemployment rate", ascending  =False)
stum.head(10)
# Out:
#                   estimated unemployment rate
# state
# Haryana                                274.77
# Tripura                                250.55
# Jharkhand                              195.39
# Bihar                                  194.71
# Delhi                                  184.14
# Puducherry                             179.42
# Himachal Pradesh                       160.65
# Rajasthan                              158.68
# Jammu & Kashmir                        148.30
# Tamil Nadu                             121.87

# %%
# State wise rate of unemplyement

sta_emp = df[["state","estimated employed"]].groupby("state").sum().sort_values(by="estimated employed", ascending =False)
sta_emp.head(10)

sta_unemp = df[["state","estimated employed"]].groupby("state").sum().sort_values(by="estimated employed", ascending =True)
sta_emp.head(10)
# Out:
#                 estimated employed
# state
# Uttar Pradesh            555247990
# Maharashtra              392047582
# West Bengal              333051643
# Bihar                    236068280
# Gujarat                  227307461
# Madhya Pradesh           223183353
# Tamil Nadu               219878981
# Karnataka                216240176
# Rajasthan                197317522
# Telangana                162440825

# %%
fig=mlt.figure()
ax0=fig.add_subplot(1,2,1)



#Unemployed
sta_unemp[:10].plot(kind="bar",color="green",figsize=(15,6),ax=ax0)
ax0.set_title("People Unemployed in each State")
ax0.set_xlabel("State")
ax0.set_ylabel("Number of People Unemployed (in %)")
# Out:
# Text(0, 0.5, 'Number of People Unemployed (in %)')

# %%
fig=mlt.figure()
ax1=fig.add_subplot(1,2,1)
# For Employed
sta_emp[:10].plot(kind="bar",color="yellow",figsize=(15,6),ax=ax1)
ax0.set_title("People Employed in each State")
ax0.set_xlabel("State")
ax0.set_ylabel("Number of People Employed (in %)")
# Out:
# Text(17.200000000000017, 0.5, 'Number of People Employed (in %)')

# %%
stum = df[["region","estimated unemployment rate"]].groupby("region").sum().sort_values(by="estimated unemployment rate", ascending  =False)
stum.head(10)
# Out:
#            estimated unemployment rate
# region
# North                          1255.28
# South                           627.28
# East                            556.64
# Northeast                       416.11
# West                            411.95

# %%
# Region wise rate of Emplyement

reg= df[["region","estimated employed"]].groupby("region").sum().sort_values(by="estimated employed", ascending =False)
reg.head()
# Out:
#            estimated employed
# region
# North              1032726546
# West                931175636
# South               842435360
# East                784094676
# Northeast           137450010

# %%
fig=mlt.figure()
ax0=fig.add_subplot(1,2,1)


#Unemployed
stum[:10].plot(kind="bar",color="blue",figsize=(15,6),ax=ax0)
ax0.set_title("People Unemployed in each Region")
ax0.set_xlabel("State")
ax0.set_ylabel("Number of People Unemployed")
# Out:
# Text(0, 0.5, 'Number of People Unemployed')

# %%
fig=mlt.figure()
ax1=fig.add_subplot(1,2,1)

#Employed
reg[:10].plot(kind="bar",color="red",figsize=(15,6),ax=ax1)
ax1.set_title("People Employed in each Region")
ax1.set_xlabel("State")
ax1.set_ylabel("Number of People Employed (in %)")
# Out:
# Text(0, 0.5, 'Number of People Employed (in %)')

# %%
df.drop(df.columns[[9]],axis=1,inplace=True)

# %%
df.head()
# Out:
#             state       date frequency  estimated unemployment rate  \
# 0  Andhra Pradesh 2020-01-31         M                         5.48
# 1  Andhra Pradesh 2020-02-29         M                         5.83
# 2  Andhra Pradesh 2020-03-31         M                         5.79
# 3  Andhra Pradesh 2020-04-30         M                        20.51
# 4  Andhra Pradesh 2020-05-31         M                        17.43
#
#    estimated employed  estimated labour participation rate region  longitude  \
# 0            16635535                                41.02  South    15.9129
# 1            16545652                                40.90  South    15.9129
# 2            15881197                                39.18  South    15.9129
# 3            11336911                                33.10  South    15.9129
# 4            12988845                                36.46  South    15.9129
#
#    latitude month
# 0     79.74   Jan
# 1     79.74   Feb
# 2     79.74   Mar
# ...

# %%
# To visulize labour participation rate & unemployment rate in each month


IND =  df.groupby(["month"])[['estimated unemployment rate', "estimated employed", "estimated labour participation rate"]].mean()
IND = pd.DataFrame(IND).reset_index()
month = IND.month
unemployment_rate = IND["estimated unemployment rate"]
labour_participation_rate = IND["estimated labour participation rate"]

fig = go.Figure()

fig.add_trace(go.Bar(x = month, y = unemployment_rate, name= "Unemployment Rate"))
fig.add_trace(go.Bar(x = month, y = labour_participation_rate, name= "Labour Participation Rate"))

fig.update_layout(title="Uneployment Rate and Labour Participation Rate",
                  xaxis={"categoryorder":"array", "categoryarray":["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct"]})

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...
